# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [12.0, 3.0]
plt.rcParams['figure.dpi'] = 200
plt.rcParams['axes.labelweight'] = 'bold'
plt.rc('font', family='NanumBarunGothic')

# %%
df = pd.read_csv('2-preprocessing/lol/news-outer.csv')

# %%
years = df.date.apply(lambda x: int(str(x)[:4]))
months = df.date.apply(lambda x: int(str(x)[4:6]))

# %%
df['year'] = years
df['month'] = months

# %%
rows = []
for y in range(2015, 2021):
    row = [y]
    for m in range(1, 13):
        if (y == 2015 and m < 8) or (y == 2020 and m > 4):
            mean = 0
        else:
            mean = int(df[(t.year == y) & (t.month == m)].view.count())
        row.append(mean)
    rows.append(row)

# %%
df2 = pd.DataFrame(rows, columns=['year', *range(1, 13)])
df2.index = df2.pop('year')
df2.columns.name = 'month'

# %%
plt.rcParams['figure.figsize'] = [11.0, 3.5]
sns.heatmap(df2, annot=True, fmt='d')

# %%
plt.rcParams['figure.figsize'] = [11.0, 3.5]
sns.heatmap(df2, annot=True, fmt='d')

# %%
plt.rcParams['figure.figsize'] = [12.0, 4.0]
sns.heatmap(df2, annot=True, fmt='d')

# %%
df3 = pd.DataFrame(list(dict(df.office.value_counts()[:15]).items()), columns=['office', 'news'])

# %%
plt.rcParams['figure.figsize'] = [15, 6]
sns.barplot(data=df3, x='office', y='news')

# %%
df.office.value_counts()
# Out:
# 데일리e스포츠     12609
# 인벤          11877
# 포모스         10038
# OSEN         6601
# 엑스포츠뉴스       1742
#             ...
# 한화생명e스포츠        1
# MBC             1
# 바스켓코리아          1
# SBS funE        1
# KBS TV          1
# Name: office, Length: 78, dtype: int64

# %%
df.view.mean()
# Out:
# 19225.235718696928

# %%
df.view.std()
# Out:
# 33876.40173637689

# %%
df.view.sum()
# Out:
# 996174814

# %%
df.view.sum() / 57
# Out:
# 17476751.12280702

# %%
df2.sum().sum() / 57
# Out:
# 909.0526315789474
